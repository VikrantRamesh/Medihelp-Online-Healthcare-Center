# %% [markdown]
# # Importing Section

# %%
import pandas as pd #for Dataframe and management
                    #creating dataframe
                    #Mainly using dataframe functions
                        #Drop
                        #rename
                        #fillna
                        #mean/median
        
import numpy as np  #used for statistical analysis
                    #RMSE
                    #Arrange function
                    #sqrt function
            
# Model Building 
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# encoding 
from sklearn.preprocessing import LabelEncoder

# Cross Validation
from sklearn.model_selection import GridSearchCV

#Evaluation libraries 
from sklearn.metrics import recall_score
from sklearn.metrics import plot_confusion_matrix, confusion_matrix
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import roc_auc_score, roc_curve

# %%
df = pd.read_csv("D:\Projects\Medical Data\dataset.csv")
df
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
#input data
Xvar = df.drop(["Disease"], axis = 1)
Xvar
# Out:
#      Symptom_1  Symptom_2  Symptom_3  Symptom_4  Symptom_5  Symptom_6  \
# 0           33         35         35         11         38         32
# 1           24         27         18         50         38         32
# 2           33         27         18         50         38         32
# 3           33         35         18         50         38         32
# 4           33         35         35         50         38         32
# ..         ...        ...        ...        ...        ...        ...
# 402         13          5         38         47         38         32
# 403         24          5         38         47         38         32
# 405         24         18         38         47         38         32
# 406         24         18          4         47         38         32
# 407         24         18          4         33         38         32
#
#      Symptom_7  Symptom_8  Symptom_9  Symptom_10  Symptom_11  Symptom_12  \
# ...

# %%
#Output data
yvar = df.Disease
yvar
# Out:
# 0      15
# 1      15
# 2      15
# 3      15
# 4      15
#        ..
# 402    27
# 403    27
# 405    27
# 406    27
# 407    27
# Name: Disease, Length: 304, dtype: int64

# %%
#split Training and testing data
X_train, X_test, y_train, y_test = train_test_split(Xvar, yvar, test_size = 0.20, random_state = 1)

# %%
X_train
# Out:
#         Symptom_1      Symptom_2              Symptom_3             Symptom_4  \
# 4444      itching      skin_rash                fatigue              lethargy
# 45      skin_rash   stomach_pain    burning_micturition   spotting_ urination
# 3393      fatigue    weight_gain   cold_hands_and_feets           mood_swings
# 3157      itching      skin_rash   nodal_skin_eruptions   dischromic _patches
# 3343   joint_pain       vomiting                fatigue        yellowish_skin
# ...           ...            ...                    ...                   ...
# 2895       chills       vomiting                fatigue           weight_loss
# 2763      itching      skin_rash                fatigue              lethargy
# 905      vomiting    sunken_eyes            dehydration                   NaN
# 3980      itching       vomiting         yellowish_skin                nausea
# 235    joint_pain       vomiting             high_fever        yellowish_skin
#
# ...

# %%
X_test
# Out:
#                  Symptom_1            Symptom_2              Symptom_3  \
# 2025   burning_micturition   bladder_discomfort    foul_smell_of urine
# 1724              vomiting          sunken_eyes              diarrhoea
# 4500               fatigue          weight_gain   cold_hands_and_feets
# 2213               itching            skin_rash               lethargy
# 4604             back_pain    weakness_in_limbs              neck_pain
# ...                    ...                  ...                    ...
# 1673               itching             vomiting                 nausea
# 368               vomiting             headache                 nausea
# 3635                chills              fatigue                  cough
# 4143          stomach_pain              acidity       ulcers_on_tongue
# 2275            joint_pain             vomiting                fatigue
#
#                 Symptom_4         Symptom_5           Symptom_6  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df = df.drop_duplicates()
df
# Out:
#               Disease    Symptom_1              Symptom_2  \
# 0    Fungal infection      itching              skin_rash
# 1    Fungal infection    skin_rash   nodal_skin_eruptions
# 2    Fungal infection      itching   nodal_skin_eruptions
# 3    Fungal infection      itching              skin_rash
# 4    Fungal infection      itching              skin_rash
# ..                ...          ...                    ...
# 402          Impetigo   high_fever                blister
# 403          Impetigo    skin_rash                blister
# 405          Impetigo    skin_rash             high_fever
# 406          Impetigo    skin_rash             high_fever
# 407          Impetigo    skin_rash             high_fever
#
#                  Symptom_3              Symptom_4 Symptom_5 Symptom_6  \
# 0     nodal_skin_eruptions    dischromic _patches       NaN       NaN
# 1      dischromic _patches                    NaN       NaN       NaN
# ...

# %%
df.nunique()
# Out:
# Disease       41
# Symptom_1     34
# Symptom_2     48
# Symptom_3     54
# Symptom_4     50
# Symptom_5     38
# Symptom_6     32
# Symptom_7     26
# Symptom_8     21
# Symptom_9     22
# Symptom_10    21
# Symptom_11    18
# Symptom_12    11
# Symptom_13     8
# Symptom_14     4
# Symptom_15     3
# Symptom_16     3
# Symptom_17     1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 304 entries, 0 to 407
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Disease     304 non-null    object
#  1   Symptom_1   304 non-null    object
#  2   Symptom_2   304 non-null    object
#  3   Symptom_3   304 non-null    object
#  4   Symptom_4   272 non-null    object
#  5   Symptom_5   234 non-null    object
#  6   Symptom_6   186 non-null    object
#  7   Symptom_7   158 non-null    object
#  8   Symptom_8   140 non-null    object
#  9   Symptom_9   120 non-null    object
#  10  Symptom_10  110 non-null    object
#  11  Symptom_11  68 non-null     object
#  12  Symptom_12  47 non-null     object
#  13  Symptom_13  30 non-null     object
#  14  Symptom_14  19 non-null     object
#  15  Symptom_15  18 non-null     object
#  16  Symptom_16  10 non-null     object
#  17  Symptom_17  1 non-null      object
# dtypes: object(18)
# memory usage: 45.1+ KB

# %% [markdown]
# # PHASE 2: ALGORTIHMS ON TRAINING DATA

# %% [markdown]
# ## Encododing DATA

# %%
le = LabelEncoder()
df = df.apply(LabelEncoder().fit_transform)
y = le.fit_transform(df.Disease)

# %%
df = df.apply(LabelEncoder().fit_transform)
df
# Out:
#      Disease  Symptom_1  Symptom_2  Symptom_3  Symptom_4  Symptom_5  \
# 0         15         33         35         35         11         38
# 1         15         24         27         18         50         38
# 2         15         33         27         18         50         38
# 3         15         33         35         18         50         38
# 4         15         33         35         35         50         38
# ..       ...        ...        ...        ...        ...        ...
# 402       27         13          5         38         47         38
# 403       27         24          5         38         47         38
# 405       27         24         18         38         47         38
# 406       27         24         18          4         47         38
# 407       27         24         18          4         33         38
#
#      Symptom_6  Symptom_7  Symptom_8  Symptom_9  Symptom_10  Symptom_11  \
# 0           32         26         21         22          21          18
# ...

# %%
svm_model = SVC()

# %%
svm_model.fit(X_train,y_train)
# Out:
# SVC()

# %%
svm_model.score(X_test,y_test)
# Out:
# 0.47540983606557374

# %% [markdown]
# ## Trail 2

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(random_state=0, class_weight='balanced')
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

# %%
result2 = accuracy_score(y_test, y_pred)
print("Accuracy: " , result2)
# Out:
# Accuracy:  0.8688524590163934

# %%
import pickle
 
# Save the trained model as a pickle string.
saved_model = pickle.dumps(rfc)

# %%
with open("Disease_model_2", "wb") as f:
    pickle.dump(rfc,f)

# %% [markdown]
# # Using the model to predict a sample

# %%
df
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
x = Xvar
X = x.head(1)

# %%
    # read data
    df = pd.read_csv("D:\Projects\Medical Data\dataset.csv")

    # read model
    model = pickle.load(open("D:\Projects\Medical Data\Disease_model_2", 'rb'))

    # Encoding the dataframe
    le = LabelEncoder()
    X_test = X_test.apply(le.fit_transform)

    df.Disease = le.fit_transform(df.Disease)
    y_pred = model.predict(X)
    print(le.inverse_transform(y_pred))
# Out:
# ['Fungal infection']
